# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# !wget https://raw.githubusercontent.com/nachikethmurthy/Source-Code-Dataset-for-Machine-Learning-using-Python/main/Data/passport.csv
# Out:
# --2024-07-13 16:23:18--  https://raw.githubusercontent.com/nachikethmurthy/Source-Code-Dataset-for-Machine-Learning-using-Python/main/Data/passport.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 295 [text/plain]
# Saving to: ‘passport.csv’
#
# passport.csv        100%[===================>]     295  --.-KB/s    in 0s
#
# 2024-07-13 16:23:18 (11.2 MB/s) - ‘passport.csv’ saved [295/295]

# %%
import pandas as pd
df = pd.read_csv("passport.csv")
df.head()
# Out:
#    processing_time
# 0             16.0
# 1             16.0
# 2             30.0
# 3             37.0
# 4             25.0

# %%
pop_std = 12.5
df.shape
# Out:
# (40, 1)

# %%
sample_mean = df.mean()[0]
sample_mean
# Out:
# 27.05

# %%
sample_std = df.std()[0]
sample_std
# Out:
# 6.246845357704713

# %%
from scipy import stats
import math
def z_test(pop_mean, pop_std, sample):
  z_score = (sample.mean() - pop_mean)/(pop_std/math.sqrt(len(sample)))
  return z_score, stats.norm.cdf(z_score)

# %%
pop_mean = 30
z_test(pop_mean, pop_std, df["processing_time"])
# Out:
# (-1.4925950555994747, 0.06777160919961511)

# %%
p = 0.06777160919961511
if p < 0.05:
  print("Reject Null Hypothesis")
else:
  print("Accept Null Hypothesis")
# Out:
# Accept Null Hypothesis

# %% [markdown]
# # 1 Sample t-test

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# !wget https://raw.githubusercontent.com/nachikethmurthy/Source-Code-Dataset-for-Machine-Learning-using-Python/main/Data/bollywoodmovies.csv
# Out:
# --2024-07-13 16:49:57--  https://raw.githubusercontent.com/nachikethmurthy/Source-Code-Dataset-for-Machine-Learning-using-Python/main/Data/bollywoodmovies.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 213 [text/plain]
# Saving to: ‘bollywoodmovies.csv’
#
# bollywoodmovies.csv 100%[===================>]     213  --.-KB/s    in 0s
#
# 2024-07-13 16:49:57 (5.42 MB/s) - ‘bollywoodmovies.csv’ saved [213/213]

# %%
df = pd.read_csv("bollywoodmovies.csv")
df.head()
# Out:
#    production_cost
# 0              601
# 1              627
# 2              330
# 3              364
# 4              562

# %%
# Null hypothesis says - mean cost is 500
# Alternate hypothesis is not equal to 500

# %%
from scipy import stats
stats.ttest_1samp(df['production_cost'], 500)
# Out:
# TtestResult(statistic=-2.2845532872667547, pvalue=0.027862556406761777, df=39)

# %%
p = 0.027
if p < 0.05:
  print("Reject Null Hypothesis")
else:
  print("Accept Null Hypothesis")
# Out:
# Reject Null Hypothesis

# %%
import numpy as np
ci = stats.norm.interval(0.95, df['production_cost'].mean(), df['production_cost'].std()/np.sqrt(len(df)))
ci
# Out:
# (369.1095351264293, 489.9904648735707)

# %% [markdown]
# # 2 Sample T-test

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# !wget https://raw.githubusercontent.com/nachikethmurthy/Source-Code-Dataset-for-Machine-Learning-using-Python/main/Data/healthdrink.xlsx
# Out:
# --2024-07-13 17:07:06--  https://raw.githubusercontent.com/nachikethmurthy/Source-Code-Dataset-for-Machine-Learning-using-Python/main/Data/healthdrink.xlsx
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 27680 (27K) [application/octet-stream]
# Saving to: ‘healthdrink.xlsx’
#
# healthdrink.xlsx    100%[===================>]  27.03K  --.-KB/s    in 0.001s
#
# 2024-07-13 17:07:06 (38.9 MB/s) - ‘healthdrink.xlsx’ saved [27680/27680]

# %%
df_yes = pd.read_excel("healthdrink.xlsx", sheet_name="healthdrink_yes")
df_no = pd.read_excel("healthdrink.xlsx", sheet_name="healthdrink_no")

# %%
df_yes.head()
# Out:
#    height_increase
# 0              8.6
# 1              5.8
# 2             10.2
# 3              8.5
# 4              6.8

# %%
df_no.head()
# Out:
#    height_increase
# 0              5.3
# 1              9.0
# 2              5.7
# 3              5.5
# 4              5.4

# %%
import seaborn as sns
sns.displot(df_yes)
sns.displot(df_no)

# %%
df_yes.head()
# Out:
#    height_increase
# 0              8.6
# 1              5.8
# 2             10.2
# 3              8.5
# 4              6.8

# %%
stats.ttest_ind(df_yes["height_increase"],df_no["height_increase"])
# Out:
# TtestResult(statistic=8.131675069083359, pvalue=1.197698592263946e-13, df=157.0)

# %%
# since p is less than 0.05 - alternate hypothesis follows

# %% [markdown]
# # Paird Sample t-test

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# !wget https://raw.githubusercontent.com/nachikethmurthy/Source-Code-Dataset-for-Machine-Learning-using-Python/main/Data/breakups.csv
# Out:
# --2024-07-13 17:15:57--  https://raw.githubusercontent.com/nachikethmurthy/Source-Code-Dataset-for-Machine-Learning-using-Python/main/Data/breakups.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 208 [text/plain]
# Saving to: ‘breakups.csv’
#
# breakups.csv        100%[===================>]     208  --.-KB/s    in 0s
#
# 2024-07-13 17:15:57 (7.74 MB/s) - ‘breakups.csv’ saved [208/208]

# %%
df = pd.read_csv("breakups.csv")

# %%
df.head()
# Out:
#    Before_Breakup  After_Breakup
# 0             470            408
# 1             354            439
# 2             496            321
# 3             351            437
# 4             349            335

# %%
stats.ttest_rel(df["Before_Breakup"],df["After_Breakup"])
# Out:
# TtestResult(statistic=-0.5375404241815106, pvalue=0.5971346738292477, df=19)

# %%
# Since p is greater than 0.05, no difference between with or without breakup
# Follows the Null Hypothesis
